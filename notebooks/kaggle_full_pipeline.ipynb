# %% [markdown]
# # Trading Bot TFT - Kaggle Runner
# This notebook clones the trading bot repository, installs required dependencies, and runs the entire end-to-end pipeline (Data Download -> Preprocessing -> Model Training -> Backtesting) on Kaggle's GPU infrastructure.

# %%
# !git clone https://github.com/TeleEng/trading_bot_TFT.git
# Out:
# Cloning into 'trading_bot_TFT'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 81 (delta 34), reused 61 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (81/81), 276.39 KiB | 9.53 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
import os
os.chdir('trading_bot_TFT')

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.10.0+cu128)
# Collecting histdata (from -r requirements.txt (line 4))
#   Downloading histdata-1.1-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (1.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 1)) (2026.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->-r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from histdata->-r requirements.txt (line 4)) (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from histdata->-r requirements.txt (line 4)) (4.13.5)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 6)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->histdata->-r requirements.txt (line 4)) (2.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->histdata->-r requirements.txt (line 4)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->histdata->-r requirements.txt (line 4)) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->histdata->-r requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->histdata->-r requirements.txt (line 4)) (2026.4.22)
# Downloading histdata-1.1-py3-none-any.whl (9.2 kB)
# Installing collected packages: histdata
# Successfully installed histdata-1.1

# %%
import os
os.chdir('src')

# %%
# Phase 1: Download tick data from histdata
# !python data_downloader.py
# Out:
# Downloading Raw 1-Minute Data from HistData.com
# Time Range: 2010 to 2026
#
# Fetching EURUSD...
#   Downloading 2010...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2010
# {'tk': '0900e2edd60ee1c8760d5017b9e78f8b', 'date': '2010', 'datemonth': '2010', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_2010.zip
#   Downloading 2011...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2011
# {'tk': 'e46e87a0377c6befa8aaa0a59b93a481', 'date': '2011', 'datemonth': '2011', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_2011.zip
#   Downloading 2012...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2012
# {'tk': '4bb833922b717734796b67b087aa2343', 'date': '2012', 'datemonth': '2012', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_2012.zip
#   Downloading 2013...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2013
# {'tk': '2471b85e57d4863368583f7bb73dbc73', 'date': '2013', 'datemonth': '2013', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_2013.zip
#   Downloading 2014...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2014
# {'tk': 'fc0dd83ac2e42d320e75251d21822b9d', 'date': '2014', 'datemonth': '2014', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_2014.zip
#   Downloading 2015...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2015
# {'tk': 'f60723e7bb2dee2c3a7a2cd073970ed4', 'date': '2015', 'datemonth': '2015', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_2015.zip
#   Downloading 2016...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2016
# {'tk': '73faf5c4a741c07d6255672658e02949', 'date': '2016', 'datemonth': '2016', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_2016.zip
#   Downloading 2017...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2017
# {'tk': '6d9d684416a1613316e633a6e3ec35e3', 'date': '2017', 'datemonth': '2017', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_2017.zip
#   Downloading 2018...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2018
# {'tk': 'f79cd6e66f8395fc6a951173f1668e8f', 'date': '2018', 'datemonth': '2018', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_2018.zip
#   Downloading 2019...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2019
# {'tk': 'c79e36fdf95309ea4da82ff965c4a299', 'date': '2019', 'datemonth': '2019', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_2019.zip
#   Downloading 2020...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2020
# {'tk': '95816ea9952ac0712df7ba9ac5c776db', 'date': '2020', 'datemonth': '2020', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_2020.zip
#   Downloading 2021...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2021
# {'tk': '9a4bc5b89e01a73480f3219f9e8269cf', 'date': '2021', 'datemonth': '2021', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_2021.zip
#   Downloading 2022...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2022
# {'tk': 'bb2df34e5bf31dcb1f87993de15be15b', 'date': '2022', 'datemonth': '2022', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_2022.zip
#   Downloading 2023...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2023
# {'tk': '3640519ec6a83d31e4ecfbdaea28f60b', 'date': '2023', 'datemonth': '2023', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_2023.zip
#   Downloading 2024...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2024
# {'tk': '917c0fcc2be4fde8ebe3879ba4447af2', 'date': '2024', 'datemonth': '2024', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_2024.zip
#   Downloading 2025...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2025
# {'tk': 'd2613ec6c212284877d0bcd027e14903', 'date': '2025', 'datemonth': '2025', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_2025.zip
#   Downloading 2026-01...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2026/1
# {'tk': '48c4cc7cfe56c2a2c469fef9870ad057', 'date': '2026', 'datemonth': '202601', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_202601.zip
#   Downloading 2026-02...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2026/2
# {'tk': '0f0c63d721aa6eb83fdd760577c1f7e2', 'date': '2026', 'datemonth': '202602', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_202602.zip
#   Downloading 2026-03...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2026/3
# {'tk': '082b5cfe5134cfb06453e0468f7b6e24', 'date': '2026', 'datemonth': '202603', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_202603.zip
#   Downloading 2026-04...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2026/4
# {'tk': '2c3bf69865c3c680f457ea4717b3592e', 'date': '2026', 'datemonth': '202604', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_202604.zip
#   Downloading 2026-05...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2026/5
# {'tk': 'e28a575efcc724978bf5a1fd3322dad1', 'date': '2026', 'datemonth': '202605', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_202605.zip
#   Downloading 2026-06...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2026/6
# {'tk': '3bb8f98a0b3e5362f52871a85f7aa2ac', 'date': '2026', 'datemonth': '202606', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'EURUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_EURUSD_M1_202606.zip
#   Downloading 2026-07...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/eurusd/2026/7
# [WARNING] Failed to fetch EURUSD for 2026-07: There is no token. Please make sure your year/month/pair is correct.Example is year=2016, month=7, pair=eurgbp
#   Combining 1-Minute data...
# [OK] Saved 6043557 raw 1-minute candles to /kaggle/working/trading_bot_TFT/data/raw/EURUSD.csv
#
# Fetching GBPUSD...
#   Downloading 2010...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2010
# {'tk': '29eb3fbf9396c6abfebfec0647919962', 'date': '2010', 'datemonth': '2010', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_2010.zip
#   Downloading 2011...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2011
# {'tk': '090dc504f796b5bee91922a7636a0541', 'date': '2011', 'datemonth': '2011', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_2011.zip
#   Downloading 2012...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2012
# {'tk': '0fd94aa36742bcfd72d35ff0adcf799e', 'date': '2012', 'datemonth': '2012', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_2012.zip
#   Downloading 2013...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2013
# {'tk': 'a0f385872f6c5e442defd7e41b02d95d', 'date': '2013', 'datemonth': '2013', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_2013.zip
#   Downloading 2014...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2014
# {'tk': 'eb6be0a62cb1c8f9c4a228cf17a330c9', 'date': '2014', 'datemonth': '2014', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_2014.zip
#   Downloading 2015...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2015
# {'tk': 'ba044901e61d92c110a40a219accf3c4', 'date': '2015', 'datemonth': '2015', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_2015.zip
#   Downloading 2016...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2016
# {'tk': 'b23c660a741a5c6c7b5e039dee3584b2', 'date': '2016', 'datemonth': '2016', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_2016.zip
#   Downloading 2017...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2017
# {'tk': '905435a252b778740621ee0f36bf83f8', 'date': '2017', 'datemonth': '2017', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_2017.zip
#   Downloading 2018...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2018
# {'tk': 'd131c58dc7532fadb0fa3410710fdf7d', 'date': '2018', 'datemonth': '2018', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_2018.zip
#   Downloading 2019...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2019
# {'tk': '1d8de2847b32ccd4fa6c87fbb707e7da', 'date': '2019', 'datemonth': '2019', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_2019.zip
#   Downloading 2020...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2020
# {'tk': 'fb8e17a3d8b489f843a7e0d55b6331a1', 'date': '2020', 'datemonth': '2020', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_2020.zip
#   Downloading 2021...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2021
# {'tk': '2f8c1432dceda27d474f2652b7f3b7f7', 'date': '2021', 'datemonth': '2021', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_2021.zip
#   Downloading 2022...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2022
# {'tk': 'b3811bf97e3d84496337cd57ca3827d2', 'date': '2022', 'datemonth': '2022', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_2022.zip
#   Downloading 2023...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2023
# {'tk': 'bc4ce1e72258dfbfda6667c784dee0fb', 'date': '2023', 'datemonth': '2023', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_2023.zip
#   Downloading 2024...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2024
# {'tk': '8128811b471d66c0ef90071808b3140c', 'date': '2024', 'datemonth': '2024', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_2024.zip
#   Downloading 2025...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2025
# {'tk': '86e1ed1ce4367601f9274246852cce68', 'date': '2025', 'datemonth': '2025', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_2025.zip
#   Downloading 2026-01...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2026/1
# {'tk': '2f187dba2328574cdaf88d910cc73ecd', 'date': '2026', 'datemonth': '202601', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_202601.zip
#   Downloading 2026-02...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2026/2
# {'tk': '2381d165342fb656e053f187cdba59a7', 'date': '2026', 'datemonth': '202602', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_202602.zip
#   Downloading 2026-03...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2026/3
# {'tk': '507255aaaeb628e70ec12b1b26b55a54', 'date': '2026', 'datemonth': '202603', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_202603.zip
#   Downloading 2026-04...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2026/4
# {'tk': '344e8db752c931ac9d3b69ecd9c48c61', 'date': '2026', 'datemonth': '202604', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_202604.zip
#   Downloading 2026-05...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2026/5
# {'tk': '8768aa59ec37b4e15818e04ceab4464d', 'date': '2026', 'datemonth': '202605', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_202605.zip
#   Downloading 2026-06...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2026/6
# {'tk': '7bedf33faf27b127e3a7fe978aa32b85', 'date': '2026', 'datemonth': '202606', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'GBPUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_GBPUSD_M1_202606.zip
#   Downloading 2026-07...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/gbpusd/2026/7
# [WARNING] Failed to fetch GBPUSD for 2026-07: There is no token. Please make sure your year/month/pair is correct.Example is year=2016, month=7, pair=eurgbp
#   Combining 1-Minute data...
# [OK] Saved 6031475 raw 1-minute candles to /kaggle/working/trading_bot_TFT/data/raw/GBPUSD.csv
#
# Fetching USDJPY...
#   Downloading 2010...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2010
# {'tk': '4a0cab8d1d55df119b6c8a8d0aa34832', 'date': '2010', 'datemonth': '2010', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_2010.zip
#   Downloading 2011...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2011
# {'tk': 'c9096de45622a25f00694b254589eda6', 'date': '2011', 'datemonth': '2011', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_2011.zip
#   Downloading 2012...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2012
# {'tk': 'dbe98a131daf1908d5f6c2de012bbd34', 'date': '2012', 'datemonth': '2012', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_2012.zip
#   Downloading 2013...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2013
# {'tk': '111e868a55ca62305a9b32c7ac8d8eee', 'date': '2013', 'datemonth': '2013', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_2013.zip
#   Downloading 2014...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2014
# {'tk': 'b97413105d1307564c402b89b2cf7621', 'date': '2014', 'datemonth': '2014', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_2014.zip
#   Downloading 2015...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2015
# {'tk': '7a55fe577d5e2ed2ebba14dd2f0184fe', 'date': '2015', 'datemonth': '2015', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_2015.zip
#   Downloading 2016...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2016
# {'tk': 'fab9cdb563a2520a07f6dd6c70f3ef12', 'date': '2016', 'datemonth': '2016', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_2016.zip
#   Downloading 2017...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2017
# {'tk': '0c093c23077f247a52bfd57592ab8f52', 'date': '2017', 'datemonth': '2017', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_2017.zip
#   Downloading 2018...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2018
# {'tk': '34155efd84b10ff3f0f0903d6336ef86', 'date': '2018', 'datemonth': '2018', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_2018.zip
#   Downloading 2019...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2019
# {'tk': 'c5f2bd3ddc0c6ac639c834df451e3b64', 'date': '2019', 'datemonth': '2019', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_2019.zip
#   Downloading 2020...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2020
# {'tk': 'c418f36f683450592b13db2563a90a05', 'date': '2020', 'datemonth': '2020', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_2020.zip
#   Downloading 2021...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2021
# {'tk': '7f6ad956d9e4adb3acf0e72e2a7f8469', 'date': '2021', 'datemonth': '2021', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_2021.zip
#   Downloading 2022...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2022
# {'tk': 'fbf32db4ff80794e91a3ae3d3e227868', 'date': '2022', 'datemonth': '2022', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_2022.zip
#   Downloading 2023...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2023
# {'tk': 'ba1ce71514e2123c51303ba5c39fb9db', 'date': '2023', 'datemonth': '2023', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_2023.zip
#   Downloading 2024...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2024
# {'tk': 'cc6c3815a5a743547104a4982f3d4bf9', 'date': '2024', 'datemonth': '2024', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_2024.zip
#   Downloading 2025...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2025
# {'tk': '7182a0b15d0dc09722ca078f36566b74', 'date': '2025', 'datemonth': '2025', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_2025.zip
#   Downloading 2026-01...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2026/1
# {'tk': 'd196cb124867b9435575b800e9fd871e', 'date': '2026', 'datemonth': '202601', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_202601.zip
#   Downloading 2026-02...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2026/2
# {'tk': '0f14a260176ab385c2105e6fa50365e5', 'date': '2026', 'datemonth': '202602', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_202602.zip
#   Downloading 2026-03...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2026/3
# {'tk': '218731226f4a7972c5bbda7af2e46cc5', 'date': '2026', 'datemonth': '202603', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_202603.zip
#   Downloading 2026-04...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2026/4
# {'tk': '6c757312c3145e2ed5004cc67b28fa35', 'date': '2026', 'datemonth': '202604', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_202604.zip
#   Downloading 2026-05...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2026/5
# {'tk': '8af09998c6d4d50ae5744ac79fc9195a', 'date': '2026', 'datemonth': '202605', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_202605.zip
#   Downloading 2026-06...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2026/6
# {'tk': '6420587efe9648fc0e9dfebfe0a30ddf', 'date': '2026', 'datemonth': '202606', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDJPY'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDJPY_M1_202606.zip
#   Downloading 2026-07...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdjpy/2026/7
# [WARNING] Failed to fetch USDJPY for 2026-07: There is no token. Please make sure your year/month/pair is correct.Example is year=2016, month=7, pair=eurgbp
#   Combining 1-Minute data...
# [OK] Saved 5953554 raw 1-minute candles to /kaggle/working/trading_bot_TFT/data/raw/USDJPY.csv
#
# Fetching USDCAD...
#   Downloading 2010...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2010
# {'tk': '82d9a8a586d76174314f7b061185bc3e', 'date': '2010', 'datemonth': '2010', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_2010.zip
#   Downloading 2011...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2011
# {'tk': '547aff9242bafc4ddd005b6240e91cc5', 'date': '2011', 'datemonth': '2011', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_2011.zip
#   Downloading 2012...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2012
# {'tk': 'd03bbbee8607d308dcd2ce76246dc56a', 'date': '2012', 'datemonth': '2012', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_2012.zip
#   Downloading 2013...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2013
# {'tk': 'c4aff40110e24c5fee60bdf05df9159c', 'date': '2013', 'datemonth': '2013', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_2013.zip
#   Downloading 2014...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2014
# {'tk': 'c7f9ad035889ef291ed8ae1ba8a7c809', 'date': '2014', 'datemonth': '2014', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_2014.zip
#   Downloading 2015...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2015
# {'tk': '1d37da3b69abbe560034c83c0c9224d8', 'date': '2015', 'datemonth': '2015', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_2015.zip
#   Downloading 2016...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2016
# {'tk': '08cfb1fa8ce5edb75e443544cccaeb88', 'date': '2016', 'datemonth': '2016', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_2016.zip
#   Downloading 2017...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2017
# {'tk': '587a13cde013b5fb82242f2686247936', 'date': '2017', 'datemonth': '2017', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_2017.zip
#   Downloading 2018...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2018
# {'tk': '220375159aaf4276dc3cfb87d9c5c9ac', 'date': '2018', 'datemonth': '2018', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_2018.zip
#   Downloading 2019...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2019
# {'tk': '473c984ae7b736613fab5c634bfc3bb2', 'date': '2019', 'datemonth': '2019', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_2019.zip
#   Downloading 2020...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2020
# {'tk': '7c88d5b685e782f3fa72f40204a532fb', 'date': '2020', 'datemonth': '2020', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_2020.zip
#   Downloading 2021...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2021
# {'tk': '7d183afd154b357d788f0b67ae6ffd21', 'date': '2021', 'datemonth': '2021', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_2021.zip
#   Downloading 2022...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2022
# {'tk': '1b66a89bee5ec9f560fbe1e8338c5983', 'date': '2022', 'datemonth': '2022', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_2022.zip
#   Downloading 2023...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2023
# {'tk': '38699cf94deca496c8333d8f77709301', 'date': '2023', 'datemonth': '2023', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_2023.zip
#   Downloading 2024...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2024
# {'tk': '75b2d0a683049f46f87bb8972108e962', 'date': '2024', 'datemonth': '2024', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_2024.zip
#   Downloading 2025...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2025
# {'tk': 'dafce0b2e3dcab0597aa6b3c80d4e844', 'date': '2025', 'datemonth': '2025', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_2025.zip
#   Downloading 2026-01...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2026/1
# {'tk': 'a1f8a9faa605ccdfd1aa9aef98576b55', 'date': '2026', 'datemonth': '202601', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_202601.zip
#   Downloading 2026-02...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2026/2
# {'tk': 'a90a774c08ac368e1cf3f0232836fc1c', 'date': '2026', 'datemonth': '202602', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_202602.zip
#   Downloading 2026-03...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2026/3
# {'tk': 'd930070926541ee57ec34e94305a4685', 'date': '2026', 'datemonth': '202603', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_202603.zip
#   Downloading 2026-04...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2026/4
# {'tk': 'e59d9bc70b2dfbf36c842032e66c4623', 'date': '2026', 'datemonth': '202604', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_202604.zip
#   Downloading 2026-05...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2026/5
# {'tk': 'ccf41d8afbfc9b559974e0e47beaf94f', 'date': '2026', 'datemonth': '202605', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_202605.zip
#   Downloading 2026-06...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2026/6
# {'tk': '3ea24ce525cd729c0d8f9998b532ad18', 'date': '2026', 'datemonth': '202606', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCAD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCAD_M1_202606.zip
#   Downloading 2026-07...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdcad/2026/7
# [WARNING] Failed to fetch USDCAD for 2026-07: There is no token. Please make sure your year/month/pair is correct.Example is year=2016, month=7, pair=eurgbp
#   Combining 1-Minute data...
# [OK] Saved 5941141 raw 1-minute candles to /kaggle/working/trading_bot_TFT/data/raw/USDCAD.csv
#
# Fetching AUDUSD...
#   Downloading 2010...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2010
# {'tk': '50e718d8476508bb97e02fee8357e606', 'date': '2010', 'datemonth': '2010', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_2010.zip
#   Downloading 2011...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2011
# {'tk': 'eb8e736e82d2f984736f8772ec41d122', 'date': '2011', 'datemonth': '2011', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_2011.zip
#   Downloading 2012...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2012
# {'tk': 'b2bd34ee3ecb3c39deb69b8aa04e627b', 'date': '2012', 'datemonth': '2012', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_2012.zip
#   Downloading 2013...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2013
# {'tk': '08d5c4baedad217745d0a3dbd7c5a345', 'date': '2013', 'datemonth': '2013', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_2013.zip
#   Downloading 2014...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2014
# {'tk': '2377544f271a74334179eda2e7e0c25a', 'date': '2014', 'datemonth': '2014', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_2014.zip
#   Downloading 2015...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2015
# {'tk': '19002f719cb3fe2d3c6e6d9174d9bf16', 'date': '2015', 'datemonth': '2015', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_2015.zip
#   Downloading 2016...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2016
# {'tk': '05d14307f581ba6066511266893c11c1', 'date': '2016', 'datemonth': '2016', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_2016.zip
#   Downloading 2017...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2017
# {'tk': '8b9ab9342759baf7ef2c064b1b100cb3', 'date': '2017', 'datemonth': '2017', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_2017.zip
#   Downloading 2018...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2018
# {'tk': '61d9daf24c6e20af70f57b0ca7a1b527', 'date': '2018', 'datemonth': '2018', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_2018.zip
#   Downloading 2019...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2019
# {'tk': 'fdc9541c8663cade1091ea0d5794d611', 'date': '2019', 'datemonth': '2019', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_2019.zip
#   Downloading 2020...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2020
# {'tk': 'bdb1dd1d30569c378a2adeefeade02ae', 'date': '2020', 'datemonth': '2020', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_2020.zip
#   Downloading 2021...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2021
# {'tk': 'e467969b39af0902527d930f366ec96e', 'date': '2021', 'datemonth': '2021', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_2021.zip
#   Downloading 2022...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2022
# {'tk': '728b9330e587d675130ddfbaccbee8f6', 'date': '2022', 'datemonth': '2022', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_2022.zip
#   Downloading 2023...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2023
# {'tk': '8017fb4288e90a5b842c90f2a175bcb1', 'date': '2023', 'datemonth': '2023', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_2023.zip
#   Downloading 2024...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2024
# {'tk': 'd3ee1059a13da667cd76fe63d962190b', 'date': '2024', 'datemonth': '2024', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_2024.zip
#   Downloading 2025...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2025
# {'tk': 'b3c313ca3e83234638f93f8d744ea8fd', 'date': '2025', 'datemonth': '2025', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_2025.zip
#   Downloading 2026-01...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2026/1
# {'tk': '297f43e0f03cb114342f2c1f433228f8', 'date': '2026', 'datemonth': '202601', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_202601.zip
#   Downloading 2026-02...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2026/2
# {'tk': '7ebabbd1cef1dca035aad3a9eda1e042', 'date': '2026', 'datemonth': '202602', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_202602.zip
#   Downloading 2026-03...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2026/3
# {'tk': 'bc55fc6edfec03e0c39cdec241954107', 'date': '2026', 'datemonth': '202603', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_202603.zip
#   Downloading 2026-04...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2026/4
# {'tk': 'a06efd36a0f4cd154a486bc8015a23c4', 'date': '2026', 'datemonth': '202604', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_202604.zip
#   Downloading 2026-05...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2026/5
# {'tk': '6fb8bfe6eb09860c1aaf4a2e27ab7f81', 'date': '2026', 'datemonth': '202605', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_202605.zip
#   Downloading 2026-06...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2026/6
# {'tk': '5d0904dc528ac6783f911e98928c6522', 'date': '2026', 'datemonth': '202606', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'AUDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_AUDUSD_M1_202606.zip
#   Downloading 2026-07...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/audusd/2026/7
# [WARNING] Failed to fetch AUDUSD for 2026-07: There is no token. Please make sure your year/month/pair is correct.Example is year=2016, month=7, pair=eurgbp
#   Combining 1-Minute data...
# [OK] Saved 6022647 raw 1-minute candles to /kaggle/working/trading_bot_TFT/data/raw/AUDUSD.csv
#
# Fetching NZDUSD...
#   Downloading 2010...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2010
# {'tk': '8401bb5d1a7201a0d9ef9bb89c63ac10', 'date': '2010', 'datemonth': '2010', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_2010.zip
#   Downloading 2011...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2011
# {'tk': '0308c116512821a0fbb423755de0de60', 'date': '2011', 'datemonth': '2011', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_2011.zip
#   Downloading 2012...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2012
# {'tk': 'b7718d2d04df3da62045598dea8220f6', 'date': '2012', 'datemonth': '2012', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_2012.zip
#   Downloading 2013...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2013
# {'tk': '515f665af67b70727de7bc4de18a3d67', 'date': '2013', 'datemonth': '2013', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_2013.zip
#   Downloading 2014...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2014
# {'tk': '5d0f9a20f9bd8383b684a47da28da4f9', 'date': '2014', 'datemonth': '2014', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_2014.zip
#   Downloading 2015...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2015
# {'tk': '73c091002fef2c230509da38e4eae590', 'date': '2015', 'datemonth': '2015', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_2015.zip
#   Downloading 2016...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2016
# {'tk': '9ef3eb22122a6228132175d5a64e8171', 'date': '2016', 'datemonth': '2016', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_2016.zip
#   Downloading 2017...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2017
# {'tk': '5c5b9929756783e2dafd6bb30450e939', 'date': '2017', 'datemonth': '2017', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_2017.zip
#   Downloading 2018...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2018
# {'tk': 'fe32bc15944198695e20a9dd0f9a0974', 'date': '2018', 'datemonth': '2018', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_2018.zip
#   Downloading 2019...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2019
# {'tk': '0c531b6d4af56660f52a6ac0c6703c2f', 'date': '2019', 'datemonth': '2019', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_2019.zip
#   Downloading 2020...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2020
# {'tk': '5611250c6b868b0f3bfe77b5d9533d19', 'date': '2020', 'datemonth': '2020', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_2020.zip
#   Downloading 2021...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2021
# {'tk': '28b21bb0bc92cbb2a92dbc2845fe1c71', 'date': '2021', 'datemonth': '2021', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_2021.zip
#   Downloading 2022...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2022
# {'tk': 'f875bcd4655835529f80f22add05ad2b', 'date': '2022', 'datemonth': '2022', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_2022.zip
#   Downloading 2023...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2023
# {'tk': '265cde923b442cb2ccda149d62de0894', 'date': '2023', 'datemonth': '2023', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_2023.zip
#   Downloading 2024...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2024
# {'tk': 'ab09c865f0153edb52564f3ad7550f9d', 'date': '2024', 'datemonth': '2024', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_2024.zip
#   Downloading 2025...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2025
# {'tk': 'f56a1102fcb597f0506a21c6abcbddc0', 'date': '2025', 'datemonth': '2025', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_2025.zip
#   Downloading 2026-01...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2026/1
# {'tk': '578a10b96ea8d7effea4e9c6630ac946', 'date': '2026', 'datemonth': '202601', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_202601.zip
#   Downloading 2026-02...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2026/2
# {'tk': '82083bc0285a9fc46d55e3cb6eec50ab', 'date': '2026', 'datemonth': '202602', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_202602.zip
#   Downloading 2026-03...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2026/3
# {'tk': '3966731f18dec477bdd1689af477bc17', 'date': '2026', 'datemonth': '202603', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_202603.zip
#   Downloading 2026-04...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2026/4
# {'tk': 'e045caf59b4f180bf5e88a3f26108d70', 'date': '2026', 'datemonth': '202604', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_202604.zip
#   Downloading 2026-05...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2026/5
# {'tk': '30d25285d63f0f860281b646b25dd6e8', 'date': '2026', 'datemonth': '202605', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_202605.zip
#   Downloading 2026-06...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2026/6
# {'tk': 'd4f1a960c425f482563168a9244040c4', 'date': '2026', 'datemonth': '202606', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'NZDUSD'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_NZDUSD_M1_202606.zip
#   Downloading 2026-07...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/nzdusd/2026/7
# [WARNING] Failed to fetch NZDUSD for 2026-07: There is no token. Please make sure your year/month/pair is correct.Example is year=2016, month=7, pair=eurgbp
#   Combining 1-Minute data...
# [OK] Saved 5952293 raw 1-minute candles to /kaggle/working/trading_bot_TFT/data/raw/NZDUSD.csv
#
# Fetching USDCHF...
#   Downloading 2010...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2010
# {'tk': '8f10b4b24e3005214714ec41eef1dfa0', 'date': '2010', 'datemonth': '2010', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_2010.zip
#   Downloading 2011...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2011
# {'tk': '86ed41b6643725e88d97b4239f216ca1', 'date': '2011', 'datemonth': '2011', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_2011.zip
#   Downloading 2012...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2012
# {'tk': '68c25fbe601cdbbf88fd5a1d64fbb310', 'date': '2012', 'datemonth': '2012', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_2012.zip
#   Downloading 2013...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2013
# {'tk': 'f9f231bc9808c8245a4c380eb95baa1b', 'date': '2013', 'datemonth': '2013', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_2013.zip
#   Downloading 2014...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2014
# {'tk': '0dc7b36444a20d79d34cc076bd3f0e5b', 'date': '2014', 'datemonth': '2014', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_2014.zip
#   Downloading 2015...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2015
# {'tk': '89a1b273327ee01232ddd182bd8b7842', 'date': '2015', 'datemonth': '2015', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_2015.zip
#   Downloading 2016...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2016
# {'tk': '0733b489adefc8d7d1cb4e3cc154f2d1', 'date': '2016', 'datemonth': '2016', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_2016.zip
#   Downloading 2017...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2017
# {'tk': 'eef14cce98c753f0f14415b9cbe02baf', 'date': '2017', 'datemonth': '2017', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_2017.zip
#   Downloading 2018...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2018
# {'tk': '68c17f80083c85a21d314a2acc1540d2', 'date': '2018', 'datemonth': '2018', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_2018.zip
#   Downloading 2019...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2019
# {'tk': 'c02b211a6bd9701bde8081e346c950d2', 'date': '2019', 'datemonth': '2019', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_2019.zip
#   Downloading 2020...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2020
# {'tk': '685d263c95b3f4ebd1c428de9852be26', 'date': '2020', 'datemonth': '2020', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_2020.zip
#   Downloading 2021...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2021
# {'tk': '113319b809a18fa6322ff8357ad49141', 'date': '2021', 'datemonth': '2021', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_2021.zip
#   Downloading 2022...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2022
# {'tk': '002df95ce0c960092666ecb043d51522', 'date': '2022', 'datemonth': '2022', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_2022.zip
#   Downloading 2023...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2023
# {'tk': 'b5a7845aa1742971c3a7fcdd59a80d4e', 'date': '2023', 'datemonth': '2023', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_2023.zip
#   Downloading 2024...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2024
# {'tk': 'fe36ee05d25ae7f2c55ebc58ea6f1b00', 'date': '2024', 'datemonth': '2024', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_2024.zip
#   Downloading 2025...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2025
# {'tk': '7d6909f740e0b577dd534b5355366ac5', 'date': '2025', 'datemonth': '2025', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_2025.zip
#   Downloading 2026-01...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2026/1
# {'tk': '61f7df49d0aa621043ef32b2fbf722e1', 'date': '2026', 'datemonth': '202601', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_202601.zip
#   Downloading 2026-02...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2026/2
# {'tk': 'bd87aeb84054598503d790d7b1c5c82b', 'date': '2026', 'datemonth': '202602', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_202602.zip
#   Downloading 2026-03...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2026/3
# {'tk': 'adbd406b9bd0648a9af7aaa4c49a42e0', 'date': '2026', 'datemonth': '202603', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_202603.zip
#   Downloading 2026-04...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2026/4
# {'tk': '50fd14d274f81ca18e681721261fcca6', 'date': '2026', 'datemonth': '202604', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_202604.zip
#   Downloading 2026-05...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2026/5
# {'tk': 'cc6918e95a2dd51fc910deb29af11686', 'date': '2026', 'datemonth': '202605', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_202605.zip
#   Downloading 2026-06...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2026/6
# {'tk': '446d4e1aa104b7f4323f08a1384e9d5b', 'date': '2026', 'datemonth': '202606', 'platform': 'ASCII', 'timeframe': 'M1', 'fxpair': 'USDCHF'}
# Wrote to /kaggle/working/trading_bot_TFT/data/raw/DAT_ASCII_USDCHF_M1_202606.zip
#   Downloading 2026-07...
# https://www.histdata.com/download-free-forex-historical-data/?/ascii/1-minute-bar-quotes/usdchf/2026/7
# [WARNING] Failed to fetch USDCHF for 2026-07: There is no token. Please make sure your year/month/pair is correct.Example is year=2016, month=7, pair=eurgbp
#   Combining 1-Minute data...
# [OK] Saved 5991231 raw 1-minute candles to /kaggle/working/trading_bot_TFT/data/raw/USDCHF.csv

# %%
# Phase 2: Feature Engineering and Data Preprocessing
# !python preprocess.py
# Out:
# --- Processing Multi-Asset Pipeline ---
# Loading & Resampling NZDUSD...
# Loading & Resampling USDCAD...
# Loading & Resampling AUDUSD...
# Loading & Resampling EURUSD...
# Loading & Resampling GBPUSD...
# Loading & Resampling USDCHF...
# Loading & Resampling USDJPY...
#
# Applying FULL features + Triple Barrier to: EURUSD...
# Applying ESSENTIAL features to: NZDUSD...
# Applying ESSENTIAL features to: USDCAD...
# Applying ESSENTIAL features to: AUDUSD...
# Applying ESSENTIAL features to: GBPUSD...
# Applying ESSENTIAL features to: USDCHF...
# Applying ESSENTIAL features to: USDJPY...
#
# [OK] Pipeline Complete! Saved to /kaggle/working/trading_bot_TFT/data/processed/EURUSD_master.csv

# %%
# Phase 3 & 4: Train Model on GPU and run Backtest
# !python main.py
# Out:
# Traceback (most recent call last):
#   File "/kaggle/working/trading_bot_TFT/src/main.py", line 17, in <module>
#     from viz import plot_tsne_and_confusion_matrix
# ModuleNotFoundError: No module named 'viz'
